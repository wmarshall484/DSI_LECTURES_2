# %%
# Render our plots inline
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)

# %%
from random import randint

def flipper(trials):
    coin_list = []
    dice_list  = []
    for each_flip in range(trials):
        coin = randint(0,100)
        if coin <= 50:
            coin_list.append('Heads')
        if coin > 50:
            coin_list.append('Tails')
        die = randint(1,6)
        dice_list.append(die)
        
    return coin_list, dice_list


times_to_flip = 100000
coins, dice = flipper(times_to_flip)
mydf = pd.DataFrame([coins, dice])
mydf = mydf.T
mydf.columns = ['Coins', 'Dice']
mydf['Ints'] = np.where(mydf['Coins'] == "Heads", 1, -1)
mydf['CumSum'] = mydf.Ints.cumsum()
mydf['CumSum'].plot()

# %%
times_to_flip = 10000
tests = 10
score = 0
score_list = []

for each in range(tests):
    coins, dice = flipper(times_to_flip)
    mydf = pd.DataFrame([coins, dice])
    mydf = mydf.T
    mydf.columns = ['Coins', 'Dice']
    mydf['Ints'] = np.where(mydf['Coins'] == "Heads", 1, -1)
    mydf['CumSum'] = mydf.Ints.cumsum()
    mydf['CumSum'].plot()
    score = mydf['Ints'].sum()
    score_list.append(score)

score_list = np.array(score_list)
score_list.sum()
# Out:
# 828

# %% [markdown]
# #

# %%
import math
mydf["Consecutives"] = 0
inarow = 1
for i in range(len(mydf)):
    if i+1 >= len(mydf): break
    current = mydf["Coins"][i]
    current_plus_one = mydf["Coins"][i+1]
    if current_plus_one == current:
        inarow += 1
    else: inarow = 1
    mydf["Consecutives"][i+1] = inarow


mydf['the_chances'] = 0.5 ** mydf['Consecutives'] 
# mydf.sort("Consecutives", ascending=False)
mydf
# Out:
#     Coins Dice  Ints  CumSum  Consecutives  the_chances
# 0   Heads    1     1       1             0     1.000000
# 1   Tails    6    -1       0             1     0.500000
# 2   Heads    3     1       1             1     0.500000
# 3   Tails    2    -1       0             1     0.500000
# 4   Tails    6    -1      -1             2     0.250000
# 5   Heads    3     1       0             1     0.500000
# 6   Heads    3     1       1             2     0.250000
# 7   Heads    5     1       2             3     0.125000
# 8   Tails    3    -1       1             1     0.500000
# 9   Tails    6    -1       0             2     0.250000
# 10  Heads    5     1       1             1     0.500000
# 11  Heads    6     1       2             2     0.250000
# 12  Heads    6     1       3             3     0.125000
# 13  Tails    2    -1       2             1     0.500000
# 14  Tails    2    -1       1             2     0.250000
# 15  Tails    4    -1       0             3     0.125000
# 16  Tails    5    -1      -1             4     0.062500
# 17  Tails    3    -1      -2             5     0.031250
# 18  Heads    1     1      -1             1     0.500000
# 19  Heads    3     1       0             2     0.250000
# 20  Heads    5     1       1             3     0.125000
# 21  Heads    6     1       2             4     0.062500
# 22  Tails    1    -1       1             1     0.500000
# 23  Heads    6     1       2             1     0.500000
# 24  Heads    2     1       3             2     0.250000
# 25  Tails    4    -1       2             1     0.500000
# 26  Heads    4     1       3             1     0.500000
# 27  Heads    6     1       4             2     0.250000
# 28  Heads    6     1       5             3     0.125000
# 29  Heads    5     1       6             4     0.062500
# 30  Heads    4     1       7             5     0.031250
# 31  Heads    1     1       8             6     0.015625
# 32  Heads    6     1       9             7     0.007812
# 33  Heads    3     1      10             8     0.003906
# 34  Tails    1    -1       9             1     0.500000
# 35  Tails    2    -1       8             2     0.250000
# 36  Tails    4    -1       7             3     0.125000
# 37  Tails    6    -1       6             4     0.062500
# 38  Tails    2    -1       5             5     0.031250
# 39  Heads    1     1       6             1     0.500000
# 40  Heads    2     1       7             2     0.250000
# 41  Heads    4     1       8             3     0.125000
# 42  Tails    4    -1       7             1     0.500000
# 43  Heads    1     1       8             1     0.500000
# 44  Heads    5     1       9             2     0.250000
# 45  Heads    6     1      10             3     0.125000
# 46  Heads    2     1      11             4     0.062500
# 47  Tails    6    -1      10             1     0.500000
# 48  Heads    6     1      11             1     0.500000
# 49  Tails    4    -1      10             1     0.500000
# 50  Tails    3    -1       9             2     0.250000
# 51  Tails    4    -1       8             3     0.125000
# 52  Heads    1     1       9             1     0.500000
# 53  Tails    6    -1       8             1     0.500000
# 54  Heads    5     1       9             1     0.500000
# 55  Heads    2     1      10             2     0.250000
# 56  Tails    3    -1       9             1     0.500000
# 57  Heads    4     1      10             1     0.500000
# 58  Heads    6     1      11             2     0.250000
# 59  Tails    5    -1      10             1     0.500000
#       ...  ...   ...     ...           ...          ...
#
# [10000 rows x 6 columns]
