# %%
# (IF YOU DONT HAVE THE BASEBALL-CSVS.ZIP GET IT HERE http://seanlahman.com/files/database/lahman-csv_2014-02-14.zip )
# I'VE RENAMED IT BASEBALL-CSVS CAUSE ITS EASIER TO TYPE
# UNZIP THE BASEBALL-CSVS.ZIP FILE
# MOVE THE UNZIPPED BASEBALL-CSVS FOLDER INSIDE THE DATA FOLDER

import pandas as pd
import vincent
# %matplotlib inline
# %matplotlib qt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dfsals = pd.read_csv('data/baseball-csvs/Salaries.csv')
dfsals.head()
# Out:
#    yearID teamID lgID   playerID   salary
# 0    1985    BAL   AL  murraed02  1472819
# 1    1985    BAL   AL   lynnfr01  1090000
# 2    1985    BAL   AL  ripkeca01   800000
# 3    1985    BAL   AL   lacyle01   725000
# 4    1985    BAL   AL  flanami01   641667

# %%
dfsals.describe()
# Out:
#              yearID           salary
# count  23956.000000     23956.000000
# mean    1999.419436   1864357.120220
# std        8.045512   3079811.630009
# min     1985.000000         0.000000
# 25%     1993.000000    250000.000000
# 50%     1999.000000    507950.000000
# 75%     2006.000000   2100000.000000
# max     2013.000000  33000000.000000

# %%
dfsals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23956 entries, 0 to 23955
# Data columns (total 5 columns):
# yearID      23956 non-null int64
# teamID      23956 non-null object
# lgID        23956 non-null object
# playerID    23956 non-null object
# salary      23956 non-null int64
# dtypes: int64(2), object(3)

# %% [markdown]
# 1. WHO HAS THE HIGHEST ONE YEAR SALARY (and how much money was it).
# 2. WHO MADE THE MOST MONEY
#
# 3. WHO WAS THE HIGHEST AVERAGE SALARY

# %%
asm = dfsals.as_matrix()
asm.shape
vals = dfsals.values
print asm.shape
print vals.shape
dfsals.salary.values.shape
# Out:
# (23956, 5)
# (23956, 5)
# (23956,)

# %%
dfsals.sort(axis=1)
testdf = dfsals.set_index('yearID')
testdf.sort_index()
x = testdf.sort_index(by='salary')
y = testdf.sort('salary')
x == y
# Out:
#        teamID  lgID playerID salary
# yearID
# 1999     True  True     True   True
# 1993     True  True     True   True
# 1993     True  True     True   True
# 1997     True  True     True   True
# 1994     True  True     True   True
# 1985     True  True     True   True
# 1986     True  True     True   True
# 1986     True  True     True   True
# 1986     True  True     True   True
# 1986     True  True     True   True
# 1986     True  True     True   True
# 1986     True  True     True   True
# 1986     True  True     True   True
# 1986     True  True     True   True
# 1986     True  True     True   True
# 1986     True  True     True   True
# 1986     True  True     True   True
# 1986     True  True     True   True
# 1986     True  True     True   True
# 1986     True  True     True   True
# 1986     True  True     True   True
# 1986     True  True     True   True
# 1986     True  True     True   True
# 1986     True  True     True   True
# 1986     True  True     True   True
# ...

# %%
alist = [1,2,3,4,5]
anotherlist = [999.99, 222.22, 333.33, 444.44, 111.11]
dft = pd.DataFrame( {'int_col': alist, 'float_col': anotherlist} )
dft['float_col'].astype(np.string_)
# Out:
# 0    999.99
# 1    222.22
# 2    333.33
# 3    444.44
# 4    111.11
# Name: float_col, dtype: object

# %%
#1:  WHO HAS THE HIGHEST ONE YEAR SALARY (and how much money was it).
dfsals.sort('salary', ascending=False).head(1)
# Out:
#        yearID teamID lgID   playerID    salary
# 20030    2009    NYA   AL  rodrial01  33000000

# %%
overall_mostmoney = dfsals.groupby('playerID')['salary'].sum()
overall_mostmoney.order(ascending=False).head(10).plot(kind='bar')

# %%
overall_mostmoney = dfsals.groupby('playerID').sum()
plotdata = overall_mostmoney.sort('salary', ascending=False)

# %%
highest_avg_sal = dfsals.groupby('playerID')['salary'].mean()
highest_avg_sal.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-49276a3d8438> in <module>()
#       1 highest_avg_sal = dfsals.groupby('playerID')['salary'].mean()
# ----> 2 highest_avg_sal.order(ascending=False).plot(kind='bar')
#
# //anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_series(series, label, kind, use_index, rot, xticks, yticks, xlim, ylim, ax, style, grid, legend, logx, logy, secondary_y, **kwds)
#    2258                      secondary_y=secondary_y, **kwds)
#    2259
# -> 2260     plot_obj.generate()
#    2261     plot_obj.draw()
#    2262
#
# //anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in generate(self)
#     903         self._add_table()
#     904         self._make_legend()
# --> 905         self._post_plot_logic()
#     906         self._adorn_subplots()
#     907
#
# ...

# %%
dfsals.groupby('playerID')['salary'].sum()
# Out:
# playerID
# aardsda01      9259750
# aasedo01       2300000
# abadan01        327000
# abadfe01        903000
# abbotje01       985000
# abbotji01     12960500
# abbotku01      4237000
# abbotky01       259000
# abbotpa01      6471000
# abercre01       327000
# abernbr01       515000
# abnersh01       723500
# abreubo01    124379666
# abreuto01      1298000
# accarje01      3274400
# ...
# zerbech01       317000
# zieglbr01      7010000
# zimmeje02     10757501
# zimmejo01       401000
# zimmejo02      8065000
# zimmery01     45592000
# ziskri01        817500
# zitoba01     137035000
# zobribe01     16695100
# zoskyed01       109000
# zuberjo01       109000
# zuletju01       200000
# zumayjo01      4207000
# zupcibo01       431000
# zuvelpa01       145000
# Name: salary, Length: 4668, dtype: int64
