# %%
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X = np.random.multivariate_normal([0,0], [[1,.8],[.8,1]], 150)
X = (X - X.mean(axis=0))/X.std(axis=0)

# %%
plt.scatter(X[:,0], X[:,1])
plt.xlabel('x1')
plt.ylabel('x2')
plt.axis('square')
# Out:
# (-3.0, 6.0, -4.0, 5.0)

# %%
pca = PCA(n_components=2)
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
V = pca.components_
v1 = V[0]
v2 = V[1]

# %%
V
# Out:
# array([[ 0.70710678,  0.70710678],
#        [ 0.70710678, -0.70710678]])

# %%
v1.dot(v2)
# Out:
# 0.0

# %%
xx1 = np.linspace(-2, 2, 10)
xx2 = np.linspace(-0.7, 0.7, 10)
line1 = (v1[1]/v1[0])*xx1 
line2 = (v2[1]/v2[0])*xx2

# %%
plt.scatter(X[:,0], X[:,1], color='k', s=10.8,alpha=0.7)
#lt.plot([0,v1[0]], [0,v1[1]], linewidth=5, color='b')
#lt.plot([0, v2[0]], [0,v2[1]], linewidth=5, color='g')
plt.plot(xx1, line1, linewidth=3, color='b')
plt.plot(xx2, line2, linewidth=3, color='g')
plt.axis('square')
plt.xlabel('x1')
plt.ylabel('x2')

# %%
plt.scatter(X[:,0], X[:,1], color='k', s=10.8,alpha=0.7)
plt.arrow(0, 0,v1[0],v1[1], linewidth=5, color='b')
plt.arrow(0, 0,v2[0],v2[1], linewidth=5, color='g')
plt.axis('square')
plt.xlabel('x1')
plt.ylabel('x2')

# %%
theta = np.pi/10

# %%
rot = np.array([[np.cos(theta), np.sin(theta)],[-np.sin(theta), np.cos(theta)]])

# %%
X_rot = X.dot(rot)

# %%
line1 = np.array([[-3,0],[3,0]])
line2 = np.array([[0,-3],[0,3]])
line1_rot = line1.dot(rot)
line2_rot = line2.dot(rot)

# %%
plt.scatter(X[:,0], X[:,1])
plt.plot(line1_rot[:,0], line1_rot[:,1], color='g', linewidth=2, alpha=0.5)
plt.plot(line2_rot[:,0], line2_rot[:,1], color='g', linewidth=2, alpha=0.5)
plt.xlabel("x1")
plt.ylabel("x2")
plt.axis('square')
# Out:
# (-4.0, 5.0, -4.0, 5.0)

# %%
plt.scatter(X_rot[:,0], X_rot[:,1])
plt.axhline(0,color='g')
plt.axvline(0, color='g')
plt.xlabel("x1'")
plt.ylabel("x2'")
plt.axis('square')
# Out:
# (-2.0, 8.0, -4.0, 6.0)

# %%
A = np.array([[0,-1],[1,0]])
x1 = np.array([[0,1]])
x2 = np.array([[1,0]])
x3 = np.array([[1,1]])

# %%
x_l = np.vstack((x1, x2, x3))

# %%
plt.scatter(x_l[:,0], x_l[:,1])
plt.axis('square')
# Out:
# (-0.20000000000000001,
#  1.2000000000000002,
#  -0.20000000000000001,
#  1.2000000000000002)

# %%
x_r = x_l.dot(A)

# %%
plt.scatter(x_r[:,0], x_r[:,1])
plt.axis('square')
# Out:
# (-0.20000000000000001,
#  1.2000000000000002,
#  -1.2000000000000002,
#  0.19999999999999996)
