# %% [markdown]
# ## Scikit-Learn Example

# %%
import matplotlib.pyplot as plt
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Make some sample data
# - Make synthetic 2D data with 4 'real' clusters

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=500,
                  n_features=2,
                  centers=4,
                  cluster_std=1,
                  center_box=(-10.0, 10.0),
                  shuffle=True,
                  random_state=0)  # For reproducibility

range_n_clusters = [2, 3, 4, 5, 6]

# %% [markdown]
# #### Scatterplot of sample data

# %%
plt.scatter(X[:,0], X[:,1])

# %% [markdown]
# ### Use 'Elbow' method to find optimal value of K

# %%
from sklearn.cluster import KMeans
ncluster_list = range(1,10)

def kmean_score(nclust):
    km = KMeans(nclust)
    km.fit(X)
    rss = -km.score(X)
    return rss

scores = [kmean_score(i) for i in range(1,10)]
plt.plot(range(1,10), scores)
plt.xlabel('K')
plt.ylabel('RSS')
plt.title('RSS versus K')

# %% [markdown]
# ### Use Silhouette scores to find optimal value of K

# %%
from sklearn.metrics import silhouette_score

def get_silhouette_score(nclust):
    km = KMeans(nclust)
    km.fit(X)
    sil_avg = silhouette_score(X, km.labels_)
    return sil_avg

sil_scores = [get_silhouette_score(i) for i in range(2,10)]
plt.plot(range(2,10), sil_scores)
plt.xlabel('K')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score vs K')

# %% [markdown]
# The maximum silhouette score is at 2 and there is a local maximum at 4

# %% [markdown]
# ### Silhouette Plots provide even more detail about each clustering

# %%
from helper import cluster_and_plot

for i in range(2,8):
    cluster_and_plot(X, i)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.470596316931
# For n_clusters = 3 The average silhouette_score is : 0.465413597075
# For n_clusters = 4 The average silhouette_score is : 0.501025306673
# For n_clusters = 5 The average silhouette_score is : 0.451370156557
# For n_clusters = 6 The average silhouette_score is : 0.412634250885
# For n_clusters = 7 The average silhouette_score is : 0.351443519518
