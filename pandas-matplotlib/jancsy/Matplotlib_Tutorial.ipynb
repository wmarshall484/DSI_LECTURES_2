# %% [markdown]
# ## Matplotlib Summary <a id='top'></a>
# My summary based on [Jake Vanderplas](http://www.astro.washington.edu/users/vanderplas/Astr599/notebooks/12_AdvancedMatplotlib)
#
# **Two interfaces**
# * [scripted](#scripted)
# * [object-oriented](#object)
#
# **Layouts**
# * [fig.add_subplot()](#addsubplot)
# * [plt.subplots()](#subplots)
# * [fig.add_axes()](#addaxes)
# * plt.GridSpec()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### [Interface: Scripted](#top) <a id='scripted'></a>

# %%
x = np.linspace(0, 10)
y1 = 2 * x
y2 = -2 * x

plt.subplot(2, 1, 1)
plt.plot(x, y1) # First plot
plt.plot(x, y2) # Second plot in same subplot
plt.title('Scripted')

plt.subplot(2, 1, 2)
plt.plot(x, y2, color='r') # Second plot in a separate subplot
plt.xlabel('x')

plt.show()

# %% [markdown]
# ###[Interface: Object-Oriented](#top) <a id='object'></a>

# %% [markdown]
# [**Using add_subplot**](#top) <a id='addsubplot'></a>
#
# Arguments = (# of Rows, # of Columns, Plot Location)

# %%
fig = plt.figure()

# ax = fig.add_suplot(111) 
ax1 = fig.add_subplot(2, 1, 1) # or 211
ax1.plot(x, y1)
ax1.plot(x, y2)
ax1.set_title('Object-Oriented')
ax1.set_xlabel('x1')

ax2 = fig.add_subplot(2, 1, 2) # or 212
ax2.plot(x, y2, color='r')
ax2.set_xlabel('x2')

plt.show()

# %% [markdown]
# [**Using subplots**](#top) <a id='subplots'></a>
#
# Arguments = (# of Rows, # of Columns)

# %%
fig, ax = plt.subplots(2, 1)
# fig, (ax1, ax2) = plt.subplots(2, 1)

ax1 = ax[0]
ax2 = ax[1]

ax1.plot(x, y1)
ax1.plot(x, y2)
ax1.set_title('Using subplots')

ax2.plot(x, y2, color='r')
ax2.set_xlabel('x')

plt.show()

# %% [markdown]
# **Using 2 dimensions**
#
# ax[i, j] = (row id, column id)

# %%
fig, ax = plt.subplots(2, 3)#, sharex=True, sharey=True)
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.2, 0.45, str((i, j)), fontsize=20)
        
plt.suptitle('2 Dimensions', size=15)
plt.show()

# %% [markdown]
# [**Using add_axes**](#top) <a id='addaxes'></a>
#
# Arguments = [left, bottom, width, height]

# %%
fig = plt.figure()

ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
ax.plot(x, y1)
ax.plot(x, y2)
ax.set_title('Using add_axes')

ax1 = fig.add_axes([0.1, 0.1, 0.25, 0.25])
ax1.plot(x, y2, color='r')
ax1.set_title('Mini plot')

ax1.tick_params(axis='x',
                which='both',
                bottom='off',
                labelbottom='off')
ax1.tick_params(axis='y',
                which='both',
                left='off',
                labelleft='off')
plt.show()

# %% [markdown]
# **DataFrame**

# %%
import pandas as pd

fig = plt.figure()

df = pd.DataFrame({'x': x, 'y1': y1, 'y2':y2})
ax1 = fig.add_subplot(2, 1, 1) # or 211
df.plot(x='x', y='y1', ax=ax1)
df.plot(x='x', y='y2', ax=ax1)
ax1.set_title('DataFrame Plot')

ax2 = fig.add_subplot(2, 1, 2) # or 212
df.plot(x='x', y='y2', color='r', ax=ax2)
ax2.set_xlabel('x')

plt.show()
